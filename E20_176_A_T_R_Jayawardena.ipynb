# %% [markdown]
# <a href="https://colab.research.google.com/github/chamudithamk/ME422-B2-Lab-Group/blob/main/E20_176_A_T_R_Jayawardena.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $$
# \textbf{E/20/176 – ME422}
# $$
#
# $$
# \textbf{TecQuipment – Vibration Analyser}
# $$
#
# Consider the TecQuipment vibration analyser setup where one end of a rigid beam is pinned and the other end is connected to the frame through a spring, while an unbalanced motor is attached to the middle section of the beam.
# ![Screenshot 2026-01-08 001622.png](data:image/png;base64,...)
