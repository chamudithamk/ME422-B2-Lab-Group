# %% [markdown]
# <a href="https://colab.research.google.com/github/chamudithamk/ME422-B2-Lab-Group/blob/main/Control/E20198_Rigid%20Body%20Control.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <div style="text-align: center; line-height: 1.5;">
#   <span style="font-size: 16px; font-weight: 700;">
#     ME422 Mechatronics Systems Lab – Rigid Body Control Systems
#   </span><br>
#   <span style="font-size: 14px; font-weight: 600;">
#     E/20/198 – C.M. Keerthisena | 18th February, 2026
#   </span>
# </div>
#
# ---

# %% [markdown]
# **Task 1: Derivation of the Mathematical Model**

# %% [markdown]
# Consider the following diagram for global and local cooridnate frames of the twin rotor intrinsic rigid body system.

# %% [markdown]
# <center>
# <div style="text-align: center;">
#   <img src="https://github.com/chamudithamk/ME422-B2-Lab-Group/blob/main/Control/Images/Rotor.png?raw=1" width="40%" style="display: block; margin: 0 auto;">
#
#   <span style="display: block; text-align: center; margin-top: 5px;"><em>Figure 1: Coordinate Frame Diagram of Twin Rotor</em></span></center>
# </div>

# %% [markdown]
# ---

# %% [markdown]
# **Task 2: Simulation of the Motion of the System for Different Inputs**

# %% [markdown]
# ---

# %% [markdown]
# **Task 3: Derivation and Simulation of a PID Controller for the Tracking Problem using Error Dynamics**

# %% [markdown]
# ---

# %% [markdown]
# **Task 4: Experimental Verification of the Stability Properties of the Controller**
