# %% [markdown]
# <a href="https://colab.research.google.com/github/chamudithamk/ME422-B2-Lab-Group/blob/main/Control/Rigid%20Body%20Control.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <div style="text-align: center; line-height: 1.5;">
#   <span style="font-size: 16px; font-weight: 700;">
#     ME422 Mechatronics Systems Lab – Rigid Body Control Systems
#   </span><br>
#   <span style="font-size: 14px; font-weight: 600;">
#     E/20/198 – C.M. Keerthisena | 18th February, 2026
#   </span>
# </div>
#
# ---
